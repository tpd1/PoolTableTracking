# %%
import torch

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Using device:', torch.cuda.get_device_name(0))
print()
# Out:
# Using device: NVIDIA GeForce RTX 4080 SUPER

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=C:\Users\tdevi\PycharmProjects\PoolTableTracking\Datasets\Pool_Ball_Dataset_v1\data.yaml epochs=100 imgsz=640
# Out:
# ...
# Ultralytics YOLOv8.1.29 ðŸš€ Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4080 SUPER, 16376MiB)
# ...
